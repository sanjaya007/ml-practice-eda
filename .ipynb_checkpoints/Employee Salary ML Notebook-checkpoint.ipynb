# %% [markdown]
# # Employee Salary Increment Prediction
# This notebook is intentionally left with empty code cells. Students must implement the solution.

# %% [markdown]
# ## Step 1: Import Libraries
# Explain required libraries like pandas, numpy, sklearn.

# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Step 2: Load Dataset
# Load the CSV file and display first few rows.

# %%
df = pd.read_csv('./Employee Salary Dataset.csv')
df
# Out:
#     EmployeeID   Name  ... IncrementPercentage  NewSalary
# 0        E0103    Ram  ...                17.0    52650.0
# 1        E0436  Chris  ...                10.0   110000.0
# 2        E0271    NaN  ...                -5.0    28500.0
# 3        E0107    Ram  ...                15.0    28750.0
# 4        E0072    NaN  ...                 NaN   130000.0
# ..         ...    ...  ...                 ...        ...
# 495      E0217         ...                18.0    29500.0
# 496      E0301   John  ...                15.0   138000.0
# 497      E0132    NaN  ...                11.0   155400.0
# 498      E0070    NaN  ...                11.0   127650.0
# 499      E0252    Ram  ...                19.0    83300.0
#
# [500 rows x 8 columns]

# %% [markdown]
# ## Step 3: Data Cleaning
# Handle missing values, incorrect entries, and data types.

# %%
print("=" * 60)
print("BASIC INFO")
print("=" * 60)
print(f"Shape: {df.shape}")
print(f"\nData Types:\n{df.dtypes}")
print(f"\nFirst 5 rows:")
df.head()
# Out:
# ============================================================
# BASIC INFO
# ============================================================
# Shape: (500, 8)
#
# Data Types:
# EmployeeID              object
# Name                    object
# Department              object
# YearsExperience        float64
# CurrentSalary          float64
# PerformanceScore        object
# IncrementPercentage    float64
# NewSalary              float64
# dtype: object
#
# First 5 rows:
#   EmployeeID   Name Department  ...  PerformanceScore  IncrementPercentage NewSalary
# 0      E0103    Ram    Unknown  ...                 B                 17.0   52650.0
# 1      E0436  Chris    Finance  ...                 3                 10.0  110000.0
# 2      E0271    NaN    Unknown  ...                 A                 -5.0   28500.0
# 3      E0107    Ram  Marketing  ...                 A                 15.0   28750.0
# 4      E0072    NaN        NaN  ...               NaN                  NaN  130000.0
#
# [5 rows x 8 columns]

# %% [markdown]
# ## Step 4: Exploratory Data Analysis
# Visualize distributions and relationships.

# %% [markdown]
# ## Step 5: Feature Encoding
# Convert categorical variables into numeric form.

# %% [markdown]
# ## Step 6: Train-Test Split
# Split dataset into training and testing sets.

# %% [markdown]
# ## Step 7: Logistic Regression Model
# Train and evaluate Logistic Regression.

# %% [markdown]
# ## Step 8: Naive Bayes Model
# Train and evaluate Naive Bayes.

# %% [markdown]
# ## Step 9: Decision Tree Model
# Train and evaluate Decision Tree.

# %% [markdown]
# ## Step 10: Support Vector Machine (SVM)
# Train and evaluate SVM.

# %% [markdown]
# ## Step 11: K-Nearest Neighbors (KNN)
# Train and evaluate KNN.

# %% [markdown]
# ## Step 12: Model Comparison
# Compare accuracy of all models.
